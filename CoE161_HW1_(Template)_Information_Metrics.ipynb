# %% [markdown]
# <a href="https://colab.research.google.com/github/briankelp/coe161_hw1/blob/main/CoE161_HW1_(Template)_Information_Metrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CoE161 Homework 1: Information Metrics

# %% [markdown]
# ## Part 1: Calculate the entropy of a file
# You are tasked to calculate the entropy of a file at the byte level. This means that you can treat the file as a random variable with $2^8=256$ possible outcomes.

# %%
# @title Make a local copy the 'bash' executable

# !cp /bin/bash /content/local_bash

# Compress the file
# !zip -r local_bash.zip /content/local_bash

# Encrypt the file
# !rm /content/local_bash_encrypted
# !gpg --batch --output /content/local_bash_encrypted --passphrase 'somepass123' -c /content/local_bash
# Out:
#   adding: content/local_bash (deflated 52%)
# rm: cannot remove '/content/local_bash_encrypted': No such file or directory
# gpg: directory '/root/.gnupg' created
# gpg: keybox '/root/.gnupg/pubring.kbx' created

# %% [markdown]
# # Practice:
# Fill in the simple coding steps below.

# %%
# @title Read 'local_bash' as a binary file and store it as a string of hexadecimal characters
# Out:
# '...'

# %%
# @title Split up the hex string into a list of bytes (2 hex characters)


# Additional: Calculate the number of bytes in the file
# Checkpoint: Length of local_bash is 1396520
# Out:
# 1396520

# %%
# @title Calculate the number of occurences of each byte and store as a Counter (dictionary) object
# See https://www.digitalocean.com/community/tutorials/python-counter-python-collections-counter

from collections import Counter
# Out:
# Counter({'7f': 2314,
#          '45': 7437,
#          '4c': 16468,
#          '46': 2393,
#          '02': 9475,
#          '01': 21615,
#          '00': 308560,
#          '03': 5809,
#          '3e': 980,
#          'f0': 1998,
#          '2e': 3008,
#          '40': 4887,
#          'a8': 1381,
#          '47': 1971,
#          '15': 4328,
#          '38': 4658,
#          '0d': 3587,
#          '1e': 3217,
#          '1d': 1796,
#          '06': 4631,
#          '04': 8328,
#          'd8': 1514,
#          '08': 16272,
#          '18': 7577,
#          '1c': 1720,
#          '88': 2100,
#          'e1': 967,
#          '10': 13725,
#          '05': 13358,
#          '6d': 3514,
#          'ef': 3877,
#          'e0': 2569,
#          '9b': 628,
#          '90': 3125,
#          '8a': 589,
#          '14': 4318,
#          '9a': 516,
#          'c0': 13347,
#          'bb': 774,
#          '28': 6507,
#          '6b': 1449,
#          'b4': 824,
#          'c4': 3847,
#          '30': 5225,
#          '68': 4353,
#          '44': 16842,
#          '53': 2540,
#          'e5': 950,
#          '74': 17023,
#          '64': 5557,
#          '50': 2523,
#          '78': 2684,
#          '12': 4843,
#          '2c': 1773,
#          '51': 829,
#          '52': 1054,
#          '70': 4417,
#          '35': 2716,
#          '2f': 1074,
#          '6c': 6223,
#          '69': 7614,
#          '62': 2198,
#          '36': 763,
#          '34': 1670,
#          '2d': 2958,
#          '6e': 6976,
#          '75': 7602,
#          '73': 7480,
#          '6f': 6989,
#          '32': 840,
#          '20': 23132,
#          '4e': 1255,
#          '55': 3240,
#          '80': 5537,
#          '7a': 796,
#          'ba': 2064,
#          '82': 711,
#          'a2': 625,
#          'd9': 732,
#          '8f': 1362,
#          '1f': 9717,
#          'ac': 787,
#          '8e': 1777,
#          'dc': 872,
#          'b6': 2611,
#          '95': 942,
#          'f6': 5669,
#          'fd': 4813,
#          '60': 1932,
#          'eb': 3379,
#          '0e': 19126,
#          '09': 3364,
#          '0c': 4303,
#          '23': 871,
#          '21': 876,
#          '4a': 1098,
#          '41': 19880,
#          '0f': 33229,
#          '42': 7306,
#          '84': 12713,
#          '8c': 2278,
#          '81': 1594,
#          '49': 8271,
#          '4d': 3972,
#          '22': 904,
#          '72': 7213,
#          '0a': 6173,
#          '13': 1082,
#          'e6': 1556,
#          'a6': 524,
#          'a4': 843,
#          '8b': 22635,
#          'a0': 1222,
#          '71': 927,
#          '91': 634,
#          '48': 54046,
#          '1b': 1319,
#          '2b': 1523,
#          '11': 3711,
#          'c2': 1957,
#          '0b': 4410,
#          '24': 19473,
#          '9c': 975,
#          '16': 1015,
#          '66': 7863,
#          '43': 2236,
#          '19': 840,
#          'd0': 1919,
#          '25': 3172,
#          '3b': 1650,
#          'b0': 1131,
#          '58': 1653,
#          '54': 4249,
#          'ca': 990,
#          'c3': 4738,
#          '96': 599,
#          '94': 1389,
#          'e8': 19750,
#          'a1': 608,
#          '98': 1482,
#          '83': 13346,
#          'c1': 1922,
#          '31': 8906,
#          'b2': 543,
#          'c9': 1838,
#          '59': 790,
#          '86': 2121,
#          '92': 535,
#          'af': 548,
#          'd1': 851,
#          'aa': 588,
#          '93': 592,
#          'd2': 2674,
#          'cc': 915,
#          '29': 2073,
#          '87': 895,
#          'a9': 673,
#          'db': 1881,
#          '3a': 1297,
#          '26': 778,
#          '3d': 4073,
#          'f4': 2244,
#          '79': 1909,
#          'f8': 4542,
#          'fb': 3524,
#          'e3': 855,
#          '3c': 2371,
#          '89': 34178,
#          '33': 985,
#          '39': 3085,
#          'b8': 2167,
#          'c8': 1685,
#          '63': 6864,
#          'cd': 794,
#          '3f': 1131,
#          '61': 7353,
#          '5f': 6007,
#          'cf': 844,
#          '1a': 902,
#          '85': 17606,
#          '07': 4668,
#          'c5': 2666,
#          '5a': 692,
#          '56': 1488,
#          'ae': 519,
#          'a5': 532,
#          'd6': 761,
#          'd5': 809,
#          '2a': 855,
#          '5d': 4146,
#          '9d': 711,
#          'da': 742,
#          '37': 739,
#          '65': 10879,
#          'bd': 887,
#          'b5': 586,
#          'f3': 4525,
#          'e4': 2023,
#          'b1': 638,
#          'fc': 3460,
#          '27': 1134,
#          'ea': 1244,
#          '5e': 1481,
#          'a7': 577,
#          '17': 1042,
#          'c6': 3112,
#          '6a': 747,
#          'e9': 8904,
#          '76': 2093,
#          'ec': 2232,
#          'ee': 2197,
#          'f1': 1405,
#          'f5': 2441,
#          'ff': 60458,
#          '4b': 1040,
#          '4f': 1164,
#          '5c': 3520,
#          '67': 2214,
#          '77': 1637,
#          '7b': 980,
#          '7c': 2976,
#          '97': 684,
#          '99': 569,
#          '9e': 608,
#          'ab': 541,
#          'b7': 616,
#          'b9': 896,
#          'be': 2703,
#          'c7': 7688,
#          'cb': 705,
#          'd3': 898,
#          'd4': 866,
#          'd7': 790,
#          'de': 881,
#          'df': 1225,
#          'e7': 2161,
#          'ed': 2487,
#          'f2': 2727,
#          'f7': 3418,
#          'f9': 2950,
#          'fe': 5493,
#          '57': 1526,
#          '5b': 2846,
#          '7e': 1331,
#          'a3': 607,
#          'bc': 1113,
#          'bf': 2340,
#          'ce': 818,
#          'dd': 870,
#          'e2': 1309,
#          'fa': 5956,
#          '7d': 1849,
#          '9f': 596,
#          '8d': 18721,
#          'b3': 480,
#          'ad': 524})

# %%
# @title Calculate the probabilities of each byte
# Out:
# [0.001656975911551571,
#  0.005325380230859565,
#  0.011792169106063644,
#  0.0017135450978145676,
#  0.006784722023315097,
#  0.015477759000945206,
#  0.2209492166241801,
#  0.004159625354452496,
#  0.0007017443359207173,
#  0.0014306991664995846,
#  0.0021539254718872624,
#  0.003499412826167903,
#  0.0009888866611290922,
#  0.00141136539397932,
#  0.0030991321284335347,
#  0.003335433792570103,
#  0.002568527482599605,
#  0.002303583192507089,
#  0.001286053905422049,
#  0.0033161000200498383,
#  0.005963394724028299,
#  0.0010841233924326183,
#  0.0116518202388795,
#  0.005425629421705382,
#  0.0012316329161057486,
#  0.001503737862687251,
#  0.0006924354824850343,
#  0.009828001031134534,
#  0.009565204937988715,
#  0.00251625469023,
#  0.0027761865207802253,
#  0.0018395726520207374,
#  0.000449689227508378,
#  0.0022377051528084096,
#  0.000421762667201329,
#  0.003091971471944548,
#  0.00036948987483172456,
#  0.009557328215850829,
#  0.0005542348122475868,
#  0.004659439177383783,
#  0.0010375791252542033,
#  0.0005900380946925214,
#  0.0027547045513132643,
#  0.003741443015495661,
#  0.003117033769656002,
#  0.012059977658751754,
#  0.0018188067482026752,
#  0.0006802623664537565,
#  0.012189585541202417,
#  0.003979176810930026,
#  0.0018066336321713975,
#  0.0019219202016440868,
#  0.0034679059376163607,
#  0.0012695843954973792,
#  0.0005936184229370149,
#  0.0007547331939392203,
#  0.003162861971185518,
#  0.0019448343024088448,
#  0.0007690545069171941,
#  0.0044560765330965545,
#  0.005452123850714634,
#  0.001573912296279323,
#  0.0005463580901097012,
#  0.001195829633660814,
#  0.002118122189442328,
#  0.0049952739667172685,
#  0.005443531062927849,
#  0.005356171053762209,
#  0.005004582820152951,
#  0.0006014951450749005,
#  0.016564030590324522,
#  0.0008986623893678572,
#  0.0010655056855612523,
#  0.00037163807177842065,
#  0.00038094692521410364,
#  0.0005449259588119039,
#  0.000579297109959041,
#  0.0006122361298083808,
#  0.002968808180333973,
#  0.0005091226763669694,
#  0.0005313207114828288,
#  0.0005291725145361326,
#  0.007790078194368859,
#  0.0006351502305731389,
#  0.00041961447025463293,
#  0.003240197061266577,
#  0.001448600807722052,
#  0.0004568498839973649,
#  0.002477587145189471,
#  0.0008120184458511156,
#  0.0008907856672299716,
#  0.0010604932260189614,
#  0.0004131698794145447,
#  0.0007461404061524361,
#  0.0022283962993727264,
#  0.0005349010397273222,
#  0.006375848537793945,
#  0.0014987254031449604,
#  0.0015982585283418785,
#  0.0015731962306304243,
#  0.001006072236702661,
#  0.0017479162489617047,
#  0.04329189700111706,
#  0.0007447082748546387,
#  0.0008335004153180764,
#  0.0025205510841233925,
#  0.001585369346661702,
#  0.0011721994672471573,
#  0.0007017443359207173,
#  0.0021310113711225046,
#  0.0004897889038467046,
#  0.0004074413542233552,
#  0.00043536791453040413,
#  0.00038739151605419184,
#  0.0004410964397215937,
#  0.0006415948214132271,
#  0.0019355254489731618,
#  0.005505112708733137,
#  0.0005048262824735772,
#  0.0006430269527110245,
#  0.0006201128519462664,
#  0.0005656918626299659,
#  0.0006308538366797468,
#  0.0008771804199008965,
#  0.0015474178672700712,
#  0.0017808552688110446,
#  0.0019527110245467305,
#  0.002447512387935726,
#  0.0021123936642511386,
#  0.00393334860940051,
#  0.0010927161802194024,
#  0.0020379228367656747,
#  0.0009530833786841578,
#  0.00043465184888150544,
#  0.0007969810672242431,
#  0.001675593618422937,
#  0.0005857417007991293,
#  0.0006229771145418612,
#  0.0009373299344083866,
#  0.004264887004840604,
#  0.0013240053848136797,
#  0.00042677512674361984,
#  0.013405465013032395,
#  0.0003437115114713717,
#  0.0003752184000229141]

# %%
# @title Calculate the entropy of the file
import numpy as np
# Out:
# 6.1923858838643095

# %% [markdown]
# #Create a function that determines the byte-wise entropy of a file.

# %%
# @title Fuction to calculate the entropy of a file

def calculate_entropy(file_path):

  from collections import Counter
  import numpy as np


  return f_entropy

filesIn = ['/content/local_bash', '/content/local_bash.zip', '/content/local_bash_encrypted']
ent = [calculate_entropy(f) for f in filesIn]
ent
# Out:
# [6.1923858838643095, 7.9934788035119775, 7.999715177555571]

# %% [markdown]
# # Answer the following questions:

# %% [markdown]
# 1. What is the maximum bit-wise entropy of a file? When will this occur?
#
# Answer here:

# %% [markdown]
# 2. How can you interpret the entropy of the compressed file? Why would this result in smaller file sizes?
#
# Answer here:

# %% [markdown]
# 3. How can you interpret the entropy of the encrypted file? Why would this be an effective way of hiding information?
#
# Answer here:

# %% [markdown]
# 4. Entropy is sometimes used to check for malicious files. Can you explain why?
#
# Answer here:
